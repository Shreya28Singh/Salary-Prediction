# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
d=pd.read_csv("C:\\Users\\91930\\Desktop\\multiple_salary_data.csv")

# %%
print("Top 10 Samples:")
print(d.head(10))
# Out:
# Top 10 Samples:
#    YearsExperience  EducationYears  SkillScore        Salary
# 0         4.370861              12   75.409939  15582.830250
# 1         9.556429              15   84.790640  29952.343230
# 2         7.587945              16   92.917940  20218.986290
# 3         6.387926              15   66.297945  26333.854190
# 4         2.404168              17   61.012052   7260.393833
# 5         2.403951              16   85.557477  11087.173330
# 6         1.522753              16   90.475052   7355.877115
# 7         8.795585              14   67.433299  30700.654800
# 8         6.410035              16   54.808828  22724.424970
# 9         7.372653              15   97.026163  26464.416270

# %%
X = d.drop('Salary', axis=1)
y = d['Salary']
print(f"\nNumber of Independent Variables: {X.shape[1]}")
# Out:
# Number of Independent Variables: 3

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=32)

# %%
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# %%
y_pred = X_test_np.dot(theta)

# %%
y_pred = X_test_np.dot(theta)

plt.scatter(y_test, y_pred, color='blue')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.title('Actual vs Predicted Salary')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %%
X_train_np = np.c_[np.ones(X_train.shape[0]), X_train]
X_test_np = np.c_[np.ones(X_test.shape[0]), X_test]

# %%
theta = np.zeros(X_train_np.shape[1])
alpha = 0.01 
iterations = 1000
for i in range(iterations):
    predictions = X_train_np.dot(theta)
    errors = predictions - y_train
    gradient = (1/len(y_train)) * X_train_np.T.dot(errors)
    theta -= alpha * gradient

print("\nModel Parameters (theta values):")
print(theta)
# Out:
# Model Parameters (theta values):
# [19579.87283535  9507.15644718  2312.23441763  -363.21797378]

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)

print(f"\nMean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mse = mean_squared_error(y_test,y_pred)
#       2 mae = mean_absolute_error(y_test,y_pred)
#       4 print(f"\nMean Squared Error (MSE): {mse}")
#
# NameError: name 'y_pred' is not defined

# %%
random_sample = X_test.sample(1)
random_sample_np = np.c_[np.ones(1), random_sample]
predicted_salary = random_sample_np.dot(theta)

print("\nRandom Test Case:")
print(random_sample)
print(f"Predicted Salary: {predicted_salary[0]}")
# Out:
# Random Test Case:
#     YearsExperience  EducationYears  SkillScore
# 13        -0.829496        1.485625    0.393632
# Predicted Salary: 14985.864227526909
